# %% [markdown]
# ## 1️⃣ Import Required Dependencies

# %%
# Get the absolute path to the "src" folder
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), ".")))
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), "./src/media")))

from src.display.notebook_display import NotebookDisplay
from src.display.display_manager import DisplayManager
from src.transcription.transcriber import Transcriber
from src.media.audio_stream import AudioStream
from src.media.video_stream import VideoStream

# %%
audio_path = "/home/dev/Projects/personal/whisper_streaming_project/data/audio 1.wav"
NotebookDisplay(Transcriber(), audio_path).display_in_notebook()
# Out:
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
# ...

# %%
audio_stream = AudioStream(audio_path)
audio_stream
# Out:
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5204:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5204:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1342:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5204:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5727:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2721:(snd_pcm_open_noupdate) Unknown PCM sysdefault
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5204:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ...

# %%
# video_stream = VideoStream("sample_video.mp4")
audio_stream = AudioStream(audio_path)
transcriber = Transcriber()
display = DisplayManager()

# Start video
# video_stream.start_stream()

# Extract and transcribe audio
# audio_path = video_stream.extract_audio()
text = transcriber.transcribe(audio_path)
display.update_display(text)
# Out:
#  Baking is very good for focusing the mind because it often relies on very exact measurements.
